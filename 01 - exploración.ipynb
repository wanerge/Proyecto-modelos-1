# %% [markdown]
# #**download data directly from Kaggle**

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '.'
# !chmod 600 ./kaggle.json
# !kaggle competitions download -c udea-ai4eng-20242
# Out:
# ...
#  25% 5.00M/20.1M [00:00<00:00, 25.3MB/s]
# 100% 20.1M/20.1M [00:00<00:00, 78.8MB/s]

# %% [markdown]
# #**Unzip**

# %%
# !unzip udea*.zip > /dev/null

# %%
# !wc *.csv
# Out:
#    296787    296787   4716673 submission_example.csv
#    296787   4565553  50135751 test.csv
#    692501  10666231 118025055 train.csv
#   1286075  15528571 172877479 total

# %% [markdown]
# ## load `train.csv`

# %%
import pandas as pd
import numpy as np

z = pd.read_csv("train.csv")
print ("shape of loaded dataframe", z.shape)
# Out:
# shape of loaded dataframe (692500, 12)

# %%
z.head()
# Out:
#        ID  PERIODO         ESTU_PRGM_ACADEMICO ESTU_PRGM_DEPARTAMENTO  \
# 0  904256    20212                  ENFERMERIA                 BOGOTÁ
# 1  645256    20212                     DERECHO              ATLANTICO
# 2  308367    20203       MERCADEO Y PUBLICIDAD                 BOGOTÁ
# 3  470353    20195  ADMINISTRACION DE EMPRESAS              SANTANDER
# 4  989032    20212                  PSICOLOGIA              ANTIOQUIA
#
#              ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# 0  Entre 5.5 millones y menos de 7 millones       Menos de 10 horas
# 1  Entre 2.5 millones y menos de 4 millones                       0
# 2  Entre 2.5 millones y menos de 4 millones         Más de 30 horas
# 3  Entre 4 millones y menos de 5.5 millones                       0
# 4  Entre 2.5 millones y menos de 4 millones     Entre 21 y 30 horas
#
#   FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET                 FAMI_EDUCACIONPADRE  \
# ...

# %% [markdown]
# #**Test #1: ESTUDIANTES DE ENFERMERIA, FILTRADO POR ESTRATO MAYOR A 3**

# %%
z['FAMI_ESTRATOVIVIENDA'] = z['FAMI_ESTRATOVIVIENDA'].replace('Sin Estrato', np.nan)

z = z.dropna(subset=['FAMI_ESTRATOVIVIENDA'])

z['FAMI_ESTRATOVIVIENDA'] = z['FAMI_ESTRATOVIVIENDA'].str.replace('Estrato ', '').astype(int)

filtro = (z['ESTU_PRGM_ACADEMICO'] == 'ENFERMERIA') & (z['FAMI_ESTRATOVIVIENDA'] > 3)
z_filtrado = z[filtro]
z_filtrado.head()
# Out:
#           ID  PERIODO ESTU_PRGM_ACADEMICO ESTU_PRGM_DEPARTAMENTO  \
# 2524  343003    20203          ENFERMERIA              SANTANDER
# 3113  433897    20212          ENFERMERIA                  VALLE
# 4852  452267    20212          ENFERMERIA                  VALLE
# 5750  279796    20195          ENFERMERIA              SANTANDER
# 6372  239172    20212          ENFERMERIA                 BOGOTÁ
#
#                 ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# 2524  Entre 4 millones y menos de 5.5 millones     Entre 21 y 30 horas
# 3113  Entre 4 millones y menos de 5.5 millones                       0
# 4852  Entre 5.5 millones y menos de 7 millones     Entre 11 y 20 horas
# 5750         Entre 500 mil y menos de 1 millón                       0
# 6372                         Más de 7 millones     Entre 11 y 20 horas
#
#       FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET  \
# 2524                     4                 Si
# 3113                     4                 Si
# ...

# %% [markdown]
# #**Test #2: ESTUDIANTES DE SANTANDER, FILTRADO POR FAMILIA NO TIENE INTERNET**

# %%
filtro = (z['ESTU_PRGM_DEPARTAMENTO'] == 'SANTANDER') & (z['FAMI_TIENEINTERNET'] == 'No')
z_filtrado = z[filtro]
z_filtrado.head()
# Out:
#          ID  PERIODO                 ESTU_PRGM_ACADEMICO  \
# 405  208373    20212                INGENIERIA AMBIENTAL
# 576  364325    20183                INGENIERIA AMBIENTAL
# 652  364489    20183          ADMINISTRACION DE EMPRESAS
# 737   84937    20212            INGENIERIA EN TOPOGRAFIA
# 832  663216    20195  ADMINISTRACION PUBLICA TERRITORIAL
#
#     ESTU_PRGM_DEPARTAMENTO            ESTU_VALORMATRICULAUNIVERSIDAD  \
# 405              SANTANDER                         No pagó matrícula
# 576              SANTANDER  Entre 2.5 millones y menos de 4 millones
# 652              SANTANDER    Entre 1 millón y menos de 2.5 millones
# 737              SANTANDER    Entre 1 millón y menos de 2.5 millones
# 832              SANTANDER                          Menos de 500 mil
#
#     ESTU_HORASSEMANATRABAJA FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET  \
# 405         Más de 30 horas            Estrato 1                 No
# ...

# %% [markdown]
# #**Test #3: PORCENTAJE DE ESTUDIANTES DE ANTIOQUIA CON PROGRAMA INENIERIA EN TOPOGRAFIA

# %%
copydf = z.copy()
numberOfStudents = copydf[(copydf["ESTU_PRGM_DEPARTAMENTO"] == "ANTIOQUIA")].shape[0]
numberOfPoliticalStudents = copydf[(copydf["ESTU_PRGM_ACADEMICO"] == "CIENCIA POLITICA")].shape[0]
print("Total estudiantes antioquia: ",numberOfStudents)
print("Estudiantes de Ciencia politica en antioquia: ",numberOfPoliticalStudents)

print("El porcentaje de Esudiantes de antioquia que estudia ciencias politicas es:")
print((numberOfPoliticalStudents/numberOfStudents)*100,"%")
# Out:
# Total estudiantes antioquia:  83607
# Estudiantes de Ciencia politica en antioquia:  1423
# El porcentaje de Esudiantes de antioquia que estudia ciencias politicas es:
# 1.702010597198799 %
